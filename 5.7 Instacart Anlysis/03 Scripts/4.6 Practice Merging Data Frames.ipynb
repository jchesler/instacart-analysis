# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 4\10-2023 Instacart Basket Analysis'

# %% [markdown]
# ## Import Data

# %%
#import orders.csv
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'))

# %%
#check orders data
df_ords
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
#drop eval_set column from orders data 
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
#permanently drop eval_set column from orders data
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
#rename order_dow column to orders_day_of_week
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_day_of_week  \
# 0         2539329        1             1                  2
# 1         2398795        1             2                  3
# 2          473747        1             3                  3
# 3         2254736        1             4                  4
# 4          431534        1             5                  4
# ...           ...      ...           ...                ...
# 3421078   2266710   206209            10                  5
# 3421079   1854736   206209            11                  4
# 3421080    626363   206209            12                  1
# 3421081   2977660   206209            13                  1
# 3421082    272231   206209            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
#rename order_day_of_week to day_of_week
df_ords.rename(columns = {'order_day_of_week' : 'day_of_week'}, inplace = True)

# %%
#rename order_hour_of_day column to hour_of_day
df_ords.rename(columns = {'order_hour_of_day' : 'hour_of_day'}, inplace = True)

# %%
#check df_ords
df_ords.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#import orders_products_prior.csv
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'))

# %%
#check df_ords_prior
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#check output 
df_ords.shape
# Out:
# (3421083, 6)

# %%
#check output ords_prior
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# ## Merge Data Frames

# %%
#merge df_ords and df_ords_prior using order_id
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2539329        1             1            2            8
# 2   2539329        1             1            2            8
# 3   2539329        1             1            2            8
# 4   2539329        1             1            2            8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#shape of df_merged_large
df_merged_large.shape
# Out:
# (32434489, 10)

# %%
#check tail of df_merged_large dataframe
df_merged_large.tail()
# Out:
#           order_id  user_id  order_number  day_of_week  hour_of_day  \
# 32434484   2977660   206209            13            1           12
# 32434485   2977660   206209            13            1           12
# 32434486   2977660   206209            13            1           12
# 32434487   2977660   206209            13            1           12
# 32434488   2977660   206209            13            1           12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 32434484                     7.0       14197                  5          1
# 32434485                     7.0       38730                  6          0
# 32434486                     7.0       31477                  7          0
# 32434487                     7.0        6567                  8          0
# 32434488                     7.0       22920                  9          0
#
#          _merge
# 32434484   both
# 32434485   both
# 32434486   both
# 32434487   both
# 32434488   both

# %% [markdown]
# ## Export Data

# %%
#export cleaned orders data to prepared data folder
df_ords.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'))

# %%
#export df_merged_large as a pkl
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))
