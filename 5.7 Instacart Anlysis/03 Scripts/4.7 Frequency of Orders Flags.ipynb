# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Exercise Practice (task step 1)

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 4\10-2023 Instacart Basket Analysis'

# %%
#import orders_products_merged.pkl
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#create a subset
df_2 = df[:1000000]

# %%
#check shape
df_2.shape
# Out:
# (1000000, 14)

# %%
#create user defined function
def price_label(row):
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <=15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return 'Not enoug data'

# %%
#apply function
df_2['price_range'] = df_2.apply(price_label, axis=1)
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_8664\3588974701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['price_range'] = df_2.apply(price_label, axis=1)

# %%
df_2['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
df_2['prices'].max()
# Out:
# 14.8

# %%
df_2.loc[df_2['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\jacob\AppData\Local\Temp\ipykernel_8664\2099840035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.loc[df_2['prices'] > 15, 'price_range_loc'] = 'High-range product'
# C:\Users\jacob\AppData\Local\Temp\ipykernel_8664\2099840035.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_2.loc[df_2['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_2.loc[df_2['prices'] <= 15 & (df_2['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_2.loc[df_2['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_2['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# NaN                  756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
#frequency of orders by day of week
df['day_of_week'].value_counts(dropna = False)
# Out:
# day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#create a list for busiest, regular and least busy days of the week
result = []

for value in df["day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append ("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#create a new column titled busiest_day
df['busiest_day'] = result

# %%
#check counts of busiest day column
df['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# ## Change data types to improve memory

# %%
#check data types
df.dtypes
# Out:
# order_id                     int64
# user_id                      int64
# order_number                 int64
# day_of_week                  int64
# hour_of_day                  int64
# days_since_prior_order     float64
# product_id                   int64
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                     int64
# department_id                int64
# prices                     float64
# _merge                    category
# busiest_day                 object
# dtype: object

# %%
# change types to help memory
df['order_id']=df['order_id'].astype('int32')
df['user_id'] =df['user_id'].astype('int32')
df['order_number']=df['order_number'].astype('int8')
df['day_of_week']=df['day_of_week'].astype('int8')
df['hour_of_day']=df['hour_of_day'].astype('int8')
df['days_since_prior_order']=df['days_since_prior_order'].astype('float16')
df['product_id'] =df['product_id'].astype('int32')
df['reordered']=df['reordered'].astype('int8')
df['add_to_cart_order']=df['add_to_cart_order'].astype('int32')
df['_merge']=df['_merge'].astype('object')

# %%
#check memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int8
#  3   day_of_week             int8
#  4   hour_of_day             int8
#  5   days_since_prior_order  float16
#  6   product_id              int32
#  7   add_to_cart_order       int32
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int64
#  11  department_id           int64
#  12  prices                  float64
#  13  _merge                  object
#  14  busiest_day             object
# dtypes: float16(1), float64(1), int32(4), int64(2), int8(4), object(3)
# memory usage: 2.1+ GB

# %%
# more changes for memeber
df['aisle_id']=df['aisle_id'].astype('int32')
df['department_id']=df['department_id'].astype('int32')
df['prices']=df['prices'].astype('float16')
# Out:
# C:\users\jacob\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:134: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=True)

# %%
#check data
df.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day
# 0         Soda        77              7     9.0   both  Regularly busy
# ...

# %%
#check memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 15 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int8
#  3   day_of_week             int8
#  4   hour_of_day             int8
#  5   days_since_prior_order  float16
#  6   product_id              int32
#  7   add_to_cart_order       int32
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int32
#  11  department_id           int32
#  12  prices                  float16
#  13  _merge                  object
#  14  busiest_day             object
# dtypes: float16(2), int32(6), int8(4), object(3)
# memory usage: 1.7+ GB

# %% [markdown]
# ## Task Step 2

# %%
#create a list for the 2 busiest and 2 slowest days and all other regular days
result3 = []

for value in df["day_of_week"]:
    if value == 0 or  value == 1:
        result3.append("Busiest days")
    elif value == 3 or value == 4:
        result3.append ("Slowest days")
    else:
        result3.append("Regular days")

# %%
#create 'busyness' column and fill with result3 list
df['busyness'] =result3

# %%
#check output
df.head(25)
# Out:
#     order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0    2539329        1             1            2            8
# 1    2398795        1             2            3            7
# 2     473747        1             3            3           12
# 3    2254736        1             4            4            7
# 4     431534        1             5            4           15
# 5    3367565        1             6            2            7
# 6     550135        1             7            1            9
# 7    3108588        1             8            1           14
# 8    2295261        1             9            1           16
# 9    2550362        1            10            4            8
# 10   2968173       15            15            1            9
# 11   1870022       15            17            2           16
# 12   1911383       15            18            2           11
# 13   2715276       15            21            1            9
# ...

# %% [markdown]
# ## Step 3

# %%
#frequency table of busyness column
df['busyness'].value_counts(dropna = False)
# Out:
# busyness
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %% [markdown]
# Other than this taking me a while due to memory issues. I think it looks good. All of the days line up with their appropriate labels which is good!

# %% [markdown]
# ## Step 4

# %%
#frequency of orders per hour
df['hour_of_day'].value_counts(dropna = False)
# Out:
# hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#create grouping hours by most, average and least number of orders
hour = []

for value in df["hour_of_day"]:
    if value == 10 or  value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16 or value == 9:
        hour.append("Most orders")
    elif value == 3 or value == 4 or value == 2 or value == 5 or value == 1 or value == 0 or value == 6 or value == 23:
        hour.append ("Least orders")
    else:
        hour.append("Average orders")

# %%
hour
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
#create 'busiest_period_of_day' column and populate with hour list
df['busiest_period_of_day'] = hour

# %%
df.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# ...

# %% [markdown]
# ## Step 5

# %%
#frequency table of orders per order category
df['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Least orders       1289137
# Name: count, dtype: int64

# %% [markdown]
# ## Step 7

# %%
df.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
