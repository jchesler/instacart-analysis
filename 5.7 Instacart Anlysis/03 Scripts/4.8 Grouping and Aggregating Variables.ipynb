# %% [markdown]
# ### Step 1

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 4\10-2023 Instacart Basket Analysis'

# %%
#import orders products merged data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ### Step 2

# %%
#group data by department_id and find the mean of order_number
ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.666130
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Step 3

# %% [markdown]
# One thing that is different from the subset data frame is that all department_id values are included.
#
# antoher interesting thing is that the average number of orders per department per customer only vary on a spread of about 8 orders (15 - 23)

# %% [markdown]
# ### Step 4

# %%
#check current output of data
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge     busiest_day      busyness  \
# 0         Soda  ...    both  Regularly busy  Regular days
# 1         Soda  ...    both  Regularly busy  Slowest days
# ...

# %% [markdown]
# a loyalty flag column and was already created during the practice portion of this exercise using the followding code:
#
# ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
#
# and
#
# ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal Customer'
# ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'
# ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
#check value counts of loyalty flag
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular Customer    15876363
# Loyal Customer      10284010
# New Customer         6243788
# Name: count, dtype: int64

# %% [markdown]
# ### Clean out INF values from Prices column

# %%
#check customer spending habits based on loyalty flag
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : 'mean'})
# Out:
#                     prices
# loyalty_flag
# Loyal Customer    7.773427
# New Customer      7.801095
# Regular Customer  7.798138

# %%
#trying the same step a different way
ords_prods_merge.groupby('loyalty_flag')['prices'].mean()
# Out:
# loyalty_flag
# Loyal Customer      7.773427
# New Customer        7.801095
# Regular Customer    7.798138
# Name: prices, dtype: float64

# %%
ords_prods_merge['prices'].dtype
# Out:
# dtype('float64')

# %%
#try changing data type to see if that will get rid of inf return
ords_prods_merge['prices'] = ords_prods_merge['prices'].astype('float64')

# %%
#second attempt of checking spending based on loyalty flag
ords_prods_merge.groupby('loyalty_flag')['prices'].mean()
# Out:
# loyalty_flag
# Loyal Customer      7.773427
# New Customer        7.801095
# Regular Customer    7.798138
# Name: prices, dtype: float64

# %%
#didn't work. change data type of prices back to float 16
ords_prods_merge['prices'] = ords_prods_merge['prices'].astype('float16')

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean','min','max']})
# Out:
#                     prices
#                       mean  min   max
# loyalty_flag
# Loyal Customer    7.773427  1.0  25.0
# New Customer      7.801095  1.0  25.0
# Regular Customer  7.798138  1.0  25.0

# %%
#check to see if there are any misisng values 
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular Customer    15876363
# Loyal Customer      10284010
# New Customer         6243788
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404161, 23)

# %%
ords_prods_merge['max_order'].value_counts(dropna = False)
# Out:
# max_order
# 99    1171328
# 8      811832
# 6      811366
# 9      810185
# 7      803957
#        ...
# 97      44949
# 98      44587
# 96      40453
# 2           6
# 1           5
# Name: count, Length: 99, dtype: int64

# %%
#convert data type of prices to float
ords_prods_merge['prices'] = ords_prods_merge['prices'].astype('float')

# %%
ords_prods_merge['prices'].dtype
# Out:
# dtype('float64')

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal Customer    7.773427
# New Customer      7.801095
# Regular Customer  7.798138

# %%
ords_prods_merge['prices'].mean()
# Out:
# 7.790865257846693

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge['prices'].value_counts()
# Out:
# prices
# 12.296875    624261
# 10.296875    510496
# 4.000000     447272
# 6.300781     438467
# 1.299805     425691
# 7.300781     411924
# 8.203125     404015
# 1.400391     392209
# 6.699219     379126
# 4.500000     367223
# 4.398438     357026
# 6.800781     354168
# 7.898438     342988
# 14.296875    334811
# 13.203125    333183
# 5.699219     323997
# 1.799805     321184
# 9.101562     320782
# 4.898438     318220
# 8.796875     318091
# 3.800781     315426
# 6.898438     314196
# 14.000000    311640
# 12.796875    309727
# 11.398438    303015
# 3.599609     300127
# 1.599609     299352
# 2.000000     286259
# 11.796875    284476
# 5.300781     284243
# 7.000000     282884
# 14.703125    279291
# 6.500000     278357
# 8.296875     276230
# 4.101562     268269
# 2.900391     264700
# 1.200195     256258
# 8.601562     254009
# 3.199219     253782
# 5.199219     251509
# 5.500000     250136
# 3.099609     249256
# 2.500000     246421
# 4.199219     245755
# 6.101562     244209
# ...

# %%
#change inf values in prices column to nan
ords_prods_merge.replace([np.inf, -np.inf], np.nan, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 #change inf values in prices column to nan
# ----> 2 ords_prods_merge.replace([np.inf, -np.inf], np.nan, inplace=True)
#
# File C:\users\jacob\anaconda3\Lib\site-packages\pandas\core\generic.py:7867, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7862     if len(to_replace) != len(value):
#    7863         raise ValueError(
#    7864             f"Replacement lists must match in length. "
#    7865             f"Expecting {len(to_replace)} got {len(value)} "
#    7866         )
# -> 7867     new_data = self._mgr.replace_list(
#    7868         src_list=to_replace,
#    7869         dest_list=value,
#    7870         inplace=inplace,
#    7871         regex=regex,
#    7872     )
#    7874 elif to_replace is None:
#    7875     if not (
# ...

# %%
#check output in prices column
ords_prods_merge.isnull().sum()
# Out:
# order_id                                0
# user_id                                 0
# order_number                            0
# day_of_week                             0
# hour_of_day                             0
# days_since_prior_order            2076054
# product_id                              0
# add_to_cart_order                       0
# reordered                               0
# product_name                            0
# aisle_id                                0
# department_id                           0
# prices                               4429
# _merge                                  0
# busiest_day                             0
# busyness                                0
# busiest_period_of_day                   0
# max_order                               0
# loyalty_flag                            0
# avg_price                        32197952
# spender_flag                     32197952
# median_days_since_prior_order    32197953
# ...

# %%
#drop nan values from prices column
ords_prods_merge.dropna(subset = ['prices'], inplace = True)

# %%
#check output
ords_prods_merge.isnull().sum()

# %% [markdown]
# ### Step 5

# %%
#check customer spending habits based on loyalty flag
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean']})
# Out:
#                     prices
#                       mean
# loyalty_flag
# Loyal Customer    7.773427
# New Customer      7.801095
# Regular Customer  7.798138

# %% [markdown]
# ### Step  6

# %%
#create a new column title average price of prodcuts
#group by user_id
#find average price of goods
ords_prods_merge['avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].mean()

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge     busiest_day      busyness  \
# 0         Soda  ...    both  Regularly busy  Regular days
# 1         Soda  ...    both  Regularly busy  Slowest days
# ...

# %%
#create a spender flag 
ords_prods_merge.loc[ords_prods_merge['avg_price'] < 10, 'spender_flag'] = 'Low Spender'
ords_prods_merge.loc[(ords_prods_merge['avg_price'] >= 10), 'spender_flag'] = 'High Spender'

# %%
ords_prods_merge['spender_flag'].dtype
# Out:
# dtype('O')

# %%
ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0    2539329        1             1            2            8
# 1    2398795        1             2            3            7
# 2     473747        1             3            3           12
# 3    2254736        1             4            4            7
# 4     431534        1             5            4           15
# 5    3367565        1             6            2            7
# 6     550135        1             7            1            9
# 7    3108588        1             8            1           14
# 8    2295261        1             9            1           16
# 9    2550362        1            10            4            8
# 10   2968173       15            15            1            9
# 11   1870022       15            17            2           16
# 12   1911383       15            18            2           11
# 13   2715276       15            21            1            9
# ...

# %%
#check data types for memory
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32404161 entries, 0 to 32404858
# Data columns (total 23 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   order_id                       int32
#  1   user_id                        int32
#  2   order_number                   int8
#  3   day_of_week                    int8
#  4   hour_of_day                    int8
#  5   days_since_prior_order         float16
#  6   product_id                     int32
#  7   add_to_cart_order              int32
#  8   reordered                      int8
#  9   product_name                   object
#  10  aisle_id                       int32
#  11  department_id                  int32
#  12  prices                         float64
#  13  _merge                         object
#  14  busiest_day                    object
#  15  busyness                       object
#  16  busiest_period_of_day          object
#  17  max_order                      int8
# ...

# %%
#change data types to help memory usage
ords_prods_merge['order_id'] = ords_prods_merge['order_id'].astype('int32')

# %%
ords_prods_merge['order_id'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### Step 7

# %%
#create new column representing median days sisnce proior order
#grouped by user_id
#find median days since prior order
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].median()

# %%
#check output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge     busiest_day      busyness  \
# 0         Soda  ...    both  Regularly busy  Regular days
# 1         Soda  ...    both  Regularly busy  Slowest days
# ...

# %%
#create flag for frequent and non frequent customers
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] > 10) & (ords_prods_merge['median_days_since_prior_order'] <=20), 'frequency_flag'] = 'Regular Customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] > 20, 'frequency_flag'] = 'Non-frequent Customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
#check output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2398795        1             2            3            7
# 2    473747        1             3            3           12
# 3   2254736        1             4            4            7
# 4    431534        1             5            4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge     busiest_day      busyness  \
# 0         Soda  ...    both  Regularly busy  Regular days
# 1         Soda  ...    both  Regularly busy  Slowest days
# ...

# %%
ords_prods_merge['frequency_flag'].value_counts()
# Out:
# frequency_flag
# Frequent Customer        86596
# Regular Customer         59993
# Non-frequent Customer    59619
# Name: count, dtype: int64

# %% [markdown]
# ### Step 9

# %%
#export ords_prods_merge to pkl file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merge['spender_flag'].value_counts()
# Out:
# spender_flag
# Low Spender     201131
# High Spender      5078
# Name: count, dtype: int64
