# %% [markdown]
# # Taks 4.6

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#create path
path = r'C:\Users\jacob\Documents\Data Analytics\Data Immersion\Achievement 4\10-2023 Instacart Basket Analysis'

# %% [markdown]
# ## Step 3

# %%
#import orders_products_combined pickle
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## Step 4

# %%
#check output
df.shape
# Out:
# (32434489, 10)

# %% [markdown]
# ## Import and check products.csv

# %%
#import wrangled and cleaned products data
df_2 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_check.csv'), index_col = False)

# %%
df_2.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#drop index column from products data
df_2 = df_2.drop (columns = ['Unnamed: 0'])

# %%
#check output
df_2.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#check output of df
df.head()
# Out:
#    order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0   2539329        1             1            2            8
# 1   2539329        1             1            2            8
# 2   2539329        1             1            2            8
# 3   2539329        1             1            2            8
# 4   2539329        1             1            2            8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#drop merge flag column from previous merge so I can merge these two dataframes
df = df.drop(columns =['_merge'])

# %%
#check output
df.shape
# Out:
# (32434489, 9)

# %% [markdown]
# ## Step 5

# %% [markdown]
# product_id is the only common column between the two dataframes, so I will use it to merge them.

# %%
# merge orders (df) and products (df_2) using product_id
df_ords_prods = df.merge(df_2, on = 'product_id', indicator = True)

# %%
#check output of merge
df_ords_prods.head(50)
# Out:
#     order_id  user_id  order_number  day_of_week  hour_of_day  \
# 0    2539329        1             1            2            8
# 1    2398795        1             2            3            7
# 2     473747        1             3            3           12
# 3    2254736        1             4            4            7
# 4     431534        1             5            4           15
# 5    3367565        1             6            2            7
# 6     550135        1             7            1            9
# 7    3108588        1             8            1           14
# 8    2295261        1             9            1           16
# 9    2550362        1            10            4            8
# 10   2968173       15            15            1            9
# 11   1870022       15            17            2           16
# 12   1911383       15            18            2           11
# 13   2715276       15            21            1            9
# ...

# %% [markdown]
# ## Step 6

# %%
#check merges
df_ords_prods['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#check shape
df_ords_prods.shape
# Out:
# (32404859, 14)

# %% [markdown]
# ## Step 7

# %%
#export merged data
df_ords_prods.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
